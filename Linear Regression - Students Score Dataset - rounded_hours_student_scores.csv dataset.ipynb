# %% [markdown]
# #### Linear Regression - Students Score Dataset - rounded_hours_student_scores.csv dataset

# %% [markdown]
# ##### Is assignment mein aap given students score dataset par Linear Regression model train karein ge. Proper data handling, model building aur evaluation metrics show karna zaroori hai

# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\DAWOOD\Desktop\ML assighnment\rounded_hours_student_scores.csv')

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data
# Out:
#     Hours  Scores
# 0     1.1      41
# 1     1.2      40
# 2     1.4      38
# 3     1.5      39
# 4     1.6      36
# 5     1.8      40
# 6     1.9      42
# 7     2.1      41
# 8     2.2      45
# 9     2.3      43
# 10    2.5      40
# 11    2.6      41
# 12    2.7      49
# 13    2.9      40
# 14    3.0      42
# 15    3.2      41
# 16    3.3      36
# 17    3.4      44
# 18    3.6      45
# 19    3.7      41
# 20    3.8      47
# 21    4.0      41
# 22    4.1      48
# 23    4.3      50
# 24    4.4      46
# 25    4.5      43
# 26    4.7      42
# 27    4.8      49
# 28    4.9      47
# 29    5.1      49
# 30    5.2      48
# 31    5.4      40
# 32    5.5      41
# 33    5.6      43
# 34    5.8      45
# 35    5.9      46
# 36    6.0      50
# 37    6.2      50
# 38    6.3      49
# 39    6.5      50
# 40    6.6      47
# 41    6.7      48
# 42    6.9      52
# 43    7.0      51
# 44    7.1      50
# 45    7.3      51
# 46    7.4      60
# 47    7.6      50
# 48    7.7      52
# ...

# %%
x = data[['Hours']]
y = data['Scores']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.80,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score

# %%
y_pred_test = model.predict(x_test)

# %%
r2_score(y_test,y_pred_test)
# Out:
# 0.5809502309078735

# %%
def score_predictor(predictor):
    return model.predict([[predictor]])

# %%
a = float(input('Enter Your Hours'))
score_predictor(a)
# Out:
# Enter Your Hours 1.9
# C:\Users\DAWOOD\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([40.02198053])
