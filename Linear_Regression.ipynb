# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\DAWOOD\Desktop\Machine_Learning\Student_Performance.csv')

# %%
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
df.shape
# Out:
# (10000, 6)

# %%
df.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='object')

# %%
df.rename(columns={'Hours Studied':'Hours_Studied'},inplace=True)

# %%
df.rename(columns={'Previous Scores':'Previous_Scores'},inplace=True)

# %%
df.rename(columns={'Extracurricular Activities':'Extracurricular_Activities'},inplace=True)

# %%
df.rename(columns={'Sleep Hours':'Sleep_Hours'},inplace=True)

# %%
df.rename(columns={'Sample Question Papers Practiced':'Sample_Question_Papers_Practiced'},inplace=True)

# %%
df.rename(columns={'Performance Index':'Performance_Index'},inplace=True)

# %%
df.Extracurricular_Activities.replace(['Yes','No'],[0,1],inplace=True)
# Out:
# C:\Users\DAWOOD\AppData\Local\Temp\ipykernel_3480\3123757995.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Extracurricular_Activities.replace(['Yes','No'],[0,1],inplace=True)
# ...

# %%
df
# Out:
#       Hours_Studied  Previous_Scores  Extracurricular_Activities  Sleep_Hours  \
# 0                 7               99                           0            9
# 1                 4               82                           1            4
# 2                 8               51                           0            7
# 3                 5               52                           0            5
# 4                 7               75                           1            8
# ...             ...              ...                         ...          ...
# 9995              1               49                           0            4
# 9996              7               64                           0            8
# 9997              6               83                           0            8
# 9998              9               97                           0            7
# 9999              7               74                           1            8
#
# ...

# %%
encoded_df = pd.get_dummies(df,dtype=int)

# %%
x = encoded_df.drop('Performance_Index',axis=1)
y = encoded_df.Performance_Index

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.80,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
import matplotlib.pyplot as plt

# %%
y_pred_train = model.predict(x_train)

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
r2_score(y_train,y_pred_train)
# Out:
# 0.9886898790682355

# %%
r2_score(y_test,y_pred_test)

# %%
def performance_predictor(a,b,c,d,e):
    prediction = model.predict(a,b,c,d,e)
    return prediction

# %%
a = int(input('Enter your Studied Hours'))
b = int(input('Enter your previous scores'))
c = int(input('Enter your Extracurricular Activities 0,1'))
d = int(input('Enter your Sleep Hours Hours'))
e = int(input('Enter your Sample Question Papers Practiced '))
performance_predictor(a,b,c,d,e)
# Out:
# Enter your Studied Hours 8
# Enter your previous scores 90
# Enter your Extracurricular Activities 0,1 0
# Enter your Sleep Hours Hours 10
# Enter your Sample Question Papers Practiced  1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 6
#       4 d = int(input('Enter your Sleep Hours Hours'))
#       5 e = int(input('Enter your Sample Question Papers Practiced '))
# ----> 6 performance_predictor(a,b,c,d,e)
#
# Cell In[29], line 2, in performance_predictor(a, b, c, d, e)
#       1 def performance_predictor(a,b,c,d,e):
# ----> 2     prediction = model.predict(a,b,c,d,e)
#       3     return prediction
#
# TypeError: LinearModel.predict() takes 2 positional arguments but 6 were given

# %%
import numpy as np
def performance_predictor(a, b, c, d, e):
    features = np.array([[a, b, c, d, e]])
    prediction = model.predict(features)
    return prediction[0]

a = int(input('Enter your Studied Hours: '))
b = int(input('Enter your previous scores: '))
c = int(input('Enter your Extracurricular Activities (0 for No, 1 for Yes): '))
d = int(input('Enter your Sleep Hours: '))
e = int(input('Enter your Sample Question Papers Practiced: '))

result = int(performance_predictor(a, b, c, d, e))
print(f"Predicted Performance: {result}")
# Out:
# Enter your Studied Hours:  8
# Enter your previous scores:  89
# Enter your Extracurricular Activities (0 for No, 1 for Yes):  0
# Enter your Sleep Hours:  8
# Enter your Sample Question Papers Practiced:  1
# Predicted Performance: 84
# C:\Users\DAWOOD\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
